# %%
import requests
import base64
from io import BytesIO

# %%
with open('data/BadTracksHackaton1801.txt', 'r') as file:
    binary_file = file.read().encode('utf-8')

# %%
base64_str = base64.b64encode(binary_file).decode('utf-8')

# %%
response = requests.post('http://127.0.0.1:8000/predict', json={"file": base64_str})
prediction = response.json()
prediction
# Out:
# ---------------------------------------------------------------------------
# ConnectionResetError                      Traceback (most recent call last)
# ~\anaconda3\envs\Aviahack\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     698             # Make the request on the httplib connection object.
# --> 699             httplib_response = self._make_request(
#     700                 conn,
#
# ~\anaconda3\envs\Aviahack\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     444                     # Otherwise it looks like a bug in the code.
# --> 445                     six.raise_from(e, None)
#     446         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# ...
